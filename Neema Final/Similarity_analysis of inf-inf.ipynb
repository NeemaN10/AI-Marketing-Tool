# %%
conda list
# Out:
# # packages in environment at C:\Users\neema\anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0            py39haa95532_0
# absl-py                   1.0.0                    pypi_0    pypi
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  2021.11                  py39_0
# anaconda-client           1.9.0            py39haa95532_0
# anaconda-navigator        2.1.1                    py39_0
# anaconda-project          0.10.1             pyhd3eb1b0_0
# anyio                     2.2.0            py39haa95532_2
# appdirs                   1.4.4              pyhd3eb1b0_0
# argh                      0.26.2           py39haa95532_0
# argon2-cffi               20.1.0           py39h2bbff1b_1
# arrow                     0.13.1           py39haa95532_0
# asn1crypto                1.4.0                      py_0
# astroid                   2.6.6            py39haa95532_0
# astropy                   4.3.1            py39hc7d831d_0
# astunparse                1.6.3                    pypi_0    pypi
# async_generator           1.10               pyhd3eb1b0_0
# atomicwrites              1.4.0                      py_0
# attrs                     21.2.0             pyhd3eb1b0_0
# automat                   20.2.0                     py_0    conda-forge
# autopep8                  1.5.7              pyhd3eb1b0_0
# babel                     2.9.1              pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# backports                 1.0                pyhd3eb1b0_2
# backports.functools_lru_cache 1.6.4              pyhd3eb1b0_0
# backports.shutil_get_terminal_size 1.0.0              pyhd3eb1b0_3
# backports.tempfile        1.0                pyhd3eb1b0_1
# backports.weakref         1.0.post1                  py_1
# bcrypt                    3.2.0            py39h196d8e1_0
# beautifulsoup4            4.10.0             pyh06a4308_0
# binaryornot               0.4.4              pyhd3eb1b0_1
# bitarray                  2.3.0            py39h2bbff1b_1
# bkcharts                  0.2              py39haa95532_0
# black                     19.10b0                    py_0
# blas                      1.0                         mkl
# bleach                    4.0.0              pyhd3eb1b0_0
# blosc                     1.21.0               h19a0ad4_0
# bokeh                     2.4.1            py39haa95532_0
# boto                      2.49.0           py39haa95532_0
# bottleneck                1.3.2            py39h7cc1a96_1
# brotli                    1.0.9                ha925a31_2
# brotlipy                  0.7.0           py39h2bbff1b_1003
# bs4                       0.0.1                    pypi_0    pypi
# bzip2                     1.0.8                he774522_0
# ca-certificates           2021.10.26           haa95532_2
# cached-property           1.5.2                      py_0
# cachetools                5.0.0                    pypi_0    pypi
# certifi                   2021.10.8        py39haa95532_0
# cffi                      1.14.6           py39h2bbff1b_0
# cfitsio                   3.470                he774522_6
# chardet                   4.0.0           py39haa95532_1003
# charls                    2.2.0                h6c2663c_0
# charset-normalizer        2.0.4              pyhd3eb1b0_0
# click                     8.0.3              pyhd3eb1b0_0
# cloudpickle               2.0.0              pyhd3eb1b0_0
# clyent                    1.2.2            py39haa95532_1
# colorama                  0.4.4              pyhd3eb1b0_0
# comtypes                  1.1.10          py39haa95532_1002
# conda                     4.12.0           py39hcbf5309_0    conda-forge
# conda-build               3.21.6           py39haa95532_0
# conda-content-trust       0.1.1              pyhd3eb1b0_0
# conda-env                 2.6.0                         1
# conda-pack                0.6.0              pyhd3eb1b0_0
# conda-package-handling    1.7.3            py39h8cc25b3_1
# conda-repo-cli            1.0.4              pyhd3eb1b0_0
# conda-token               0.3.0              pyhd3eb1b0_0
# conda-verify              3.4.2                      py_1
# console_shortcut          0.1.1                         4
# constantly                15.1.0                   pypi_0    pypi
# contextlib2               0.6.0.post1        pyhd3eb1b0_0
# cookiecutter              1.7.2              pyhd3eb1b0_0
# corpus                    0.4.2                    pypi_0    pypi
# cryptography              3.4.8            py39h71e12ea_0
# cssselect                 1.1.0                      py_0    conda-forge
# curl                      7.78.0               h86230a5_0
# cycler                    0.10.0           py39haa95532_0
# cython                    0.29.24          py39h604cdb4_0
# cytoolz                   0.11.0           py39h2bbff1b_0
# daal4py                   2021.3.0         py39h757b272_0
# dal                       2021.3.0           haa95532_564
# dask                      2021.10.0          pyhd3eb1b0_0
# dask-core                 2021.10.0          pyhd3eb1b0_0
# dataclasses               0.8                pyh6d0b6a4_7
# debugpy                   1.4.1            py39hd77b12b_0
# decorator                 5.1.0              pyhd3eb1b0_0
# defusedxml                0.7.1              pyhd3eb1b0_0
# diff-match-patch          20200713           pyhd3eb1b0_0
# distributed               2021.10.0        py39haa95532_0
# dnspython                 2.2.1                    pypi_0    pypi
# docutils                  0.17.1           py39haa95532_1
# elastic-transport         8.1.2                    pypi_0    pypi
# elasticsearch             8.2.2                    pypi_0    pypi
# entrypoints               0.3              py39haa95532_0
# et_xmlfile                1.1.0            py39haa95532_0
# fastcache                 1.1.0            py39h196d8e1_0
# filelock                  3.3.1              pyhd3eb1b0_1
# flake8                    3.9.2              pyhd3eb1b0_0
# flask                     1.1.2              pyhd3eb1b0_0
# flatbuffers               2.0                      pypi_0    pypi
# fonttools                 4.25.0             pyhd3eb1b0_0
# freetype                  2.10.4               hd328e21_0
# fsspec                    2021.10.1          pyhd3eb1b0_0
# future                    0.18.2           py39haa95532_1
# futures                   2.2.0                    pypi_0    pypi
# gast                      0.5.3                    pypi_0    pypi
# get_terminal_size         1.0.0                h38e98db_0
# gevent                    21.8.0           py39h2bbff1b_1
# giflib                    5.2.1                h62dcd97_0
# glob2                     0.7                pyhd3eb1b0_0
# google-auth               2.6.0                    pypi_0    pypi
# google-auth-oauthlib      0.4.6                    pypi_0    pypi
# google-pasta              0.2.0                    pypi_0    pypi
# goslate                   1.5.2                    pypi_0    pypi
# greenlet                  1.1.1            py39hd77b12b_0
# grpcio                    1.43.0                   pypi_0    pypi
# h11                       0.13.0                   pypi_0    pypi
# h5py                      3.2.1            py39h3de5c98_0
# hdf5                      1.10.6               h7ebc959_0
# heapdict                  1.0.1              pyhd3eb1b0_0
# html5lib                  1.1                pyhd3eb1b0_0
# huggingface-hub           0.9.1                    pypi_0    pypi
# hyperlink                 21.0.0             pyhd3deb0d_0    conda-forge
# icc_rt                    2019.0.0             h0cc432a_1
# icu                       58.2                 ha925a31_3
# idna                      3.2                pyhd3eb1b0_0
# imagecodecs               2021.8.26        py39ha1f97ea_0
# imageio                   2.9.0              pyhd3eb1b0_0
# imagesize                 1.2.0              pyhd3eb1b0_0
# importlib-metadata        4.8.1            py39haa95532_0
# importlib_metadata        4.8.1                hd3eb1b0_0
# incremental               21.3.0             pyhd8ed1ab_0    conda-forge
# inflection                0.5.1            py39haa95532_0
# iniconfig                 1.1.1              pyhd3eb1b0_0
# instaloader               4.9                      pypi_0    pypi
# intel-openmp              2021.4.0          haa95532_3556
# intervaltree              3.1.0              pyhd3eb1b0_0
# ipykernel                 6.4.1            py39haa95532_1
# ipython                   7.29.0           py39hd4e2768_0
# ipython_genutils          0.2.0              pyhd3eb1b0_1
# ipywidgets                7.6.5              pyhd3eb1b0_1
# isort                     5.9.3              pyhd3eb1b0_0
# itemadapter               0.5.0              pyhd8ed1ab_0    conda-forge
# itemloaders               1.0.4              pyhd8ed1ab_0    conda-forge
# itsdangerous              2.0.1              pyhd3eb1b0_0
# jdcal                     1.4.1              pyhd3eb1b0_0
# jedi                      0.18.0           py39haa95532_1
# jinja2                    2.11.3             pyhd3eb1b0_0
# jinja2-time               0.2.0              pyhd3eb1b0_2
# jmespath                  1.0.0              pyhd8ed1ab_0    conda-forge
# joblib                    1.1.0              pyhd3eb1b0_0
# jpeg                      9d                   h2bbff1b_0
# json5                     0.9.6              pyhd3eb1b0_0
# jsonschema                3.2.0              pyhd3eb1b0_2
# jupyter                   1.0.0            py39haa95532_7
# jupyter_client            6.1.12             pyhd3eb1b0_0
# jupyter_console           6.4.0              pyhd3eb1b0_0
# jupyter_core              4.8.1            py39haa95532_0
# jupyter_server            1.4.1            py39haa95532_0
# jupyterlab                3.2.1              pyhd3eb1b0_1
# jupyterlab_pygments       0.1.2                      py_0
# jupyterlab_server         2.8.2              pyhd3eb1b0_0
# jupyterlab_widgets        1.0.0              pyhd3eb1b0_1
# keras                     2.8.0                    pypi_0    pypi
# keras-preprocessing       1.1.2                    pypi_0    pypi
# keyring                   23.1.0           py39haa95532_0
# kiwisolver                1.3.1            py39hd77b12b_0
# krb5                      1.19.2               h5b6d351_0
# lazy-object-proxy         1.6.0            py39h2bbff1b_0
# lcms2                     2.12                 h83e58a3_0
# lerc                      3.0                  hd77b12b_0
# libaec                    1.0.4                h33f27b4_1
# libarchive                3.4.2                h5e25573_0
# libclang                  13.0.0                   pypi_0    pypi
# libcurl                   7.78.0               h86230a5_0
# libdeflate                1.8                  h2bbff1b_5
# libiconv                  1.15                 h1df5818_7
# liblief                   0.10.1               hd77b12b_1
# libpng                    1.6.37               h2a8f88b_0
# libspatialindex           1.9.3                h6c2663c_0
# libssh2                   1.9.0                h7a1dbc1_1
# libtiff                   4.2.0                hd0e1b90_0
# libwebp                   1.2.0                h2bbff1b_0
# libxml2                   2.9.12               h0ad7f3c_0
# libxslt                   1.1.34               he774522_0
# libzopfli                 1.0.3                ha925a31_0
# llvmlite                  0.37.0           py39h23ce68f_1
# locket                    0.2.1            py39haa95532_1
# lxml                      4.6.3            py39h9b66d53_0
# lz4-c                     1.9.3                h2bbff1b_1
# lzo                       2.10                 he774522_2
# m2w64-gcc-libgfortran     5.3.0                         6
# m2w64-gcc-libs            5.3.0                         7
# m2w64-gcc-libs-core       5.3.0                         7
# m2w64-gmp                 6.1.0                         2
# m2w64-libwinpthread-git   5.0.0.4634.697f757               2
# markdown                  3.3.6                    pypi_0    pypi
# markupsafe                1.1.1            py39h2bbff1b_0
# matplotlib                3.4.3            py39haa95532_0
# matplotlib-base           3.4.3            py39h49ac443_0
# matplotlib-inline         0.1.2              pyhd3eb1b0_2
# mccabe                    0.6.1            py39haa95532_1
# menuinst                  1.4.18           py39h59b6b97_0
# mistune                   0.8.4           py39h2bbff1b_1000
# mkl                       2021.4.0           haa95532_640
# mkl-service               2.4.0            py39h2bbff1b_0
# mkl_fft                   1.3.1            py39h277e83a_0
# mkl_random                1.2.2            py39hf11a4ad_0
# mlxtend                   0.19.0                   pypi_0    pypi
# mne                       1.0.0                    pypi_0    pypi
# mock                      4.0.3              pyhd3eb1b0_0
# more-itertools            8.10.0             pyhd3eb1b0_0
# mpmath                    1.2.1            py39haa95532_0
# msgpack-python            1.0.2            py39h59b6b97_1
# msys2-conda-epoch         20160418                      1
# multipledispatch          0.6.0            py39haa95532_0
# Note: you may need to restart the kernel to use updated packages.
# munkres                   1.1.4                      py_0
# mypy_extensions           0.4.3            py39haa95532_0
# navigator-updater         0.2.1            py39haa95532_0
# nbclassic                 0.2.6              pyhd3eb1b0_0
# nbclient                  0.5.3              pyhd3eb1b0_0
# nbconvert                 6.1.0            py39haa95532_0
# nbformat                  5.1.3              pyhd3eb1b0_0
# nest-asyncio              1.5.1              pyhd3eb1b0_0
# networkx                  2.6.3              pyhd3eb1b0_0
# nltk                      3.6.5              pyhd3eb1b0_0
# nose                      1.3.7           pyhd3eb1b0_1006
# notebook                  6.4.5            py39haa95532_0
# numba                     0.54.1           py39hf11a4ad_0
# numexpr                   2.7.3            py39hb80d3ca_1
# numpy                     1.20.3           py39ha4e8547_0
# numpy-base                1.20.3           py39hc2deb75_0
# numpydoc                  1.1.0              pyhd3eb1b0_1
# oauthlib                  3.2.0                    pypi_0    pypi
# olefile                   0.46               pyhd3eb1b0_0
# openjpeg                  2.4.0                h4fc8c34_0
# openpyxl                  3.0.9              pyhd3eb1b0_0
# openssl                   1.1.1l               h2bbff1b_0
# opt-einsum                3.3.0                    pypi_0    pypi
# outcome                   1.1.0                    pypi_0    pypi
# packaging                 21.0               pyhd3eb1b0_0
# pandas                    1.3.4            py39h6214cd6_0
# pandocfilters             1.4.3            py39haa95532_1
# paramiko                  2.7.2                      py_0
# parsel                    1.6.0                      py_0    conda-forge
# parso                     0.8.2              pyhd3eb1b0_0
# partd                     1.2.0              pyhd3eb1b0_0
# path                      16.0.0           py39haa95532_0
# path.py                   12.5.0               hd3eb1b0_0
# pathlib2                  2.3.6            py39haa95532_2
# pathspec                  0.7.0                      py_0
# patsy                     0.5.2            py39haa95532_0
# pep8                      1.7.1            py39haa95532_0
# pexpect                   4.8.0              pyhd3eb1b0_3
# pickleshare               0.7.5           pyhd3eb1b0_1003
# pillow                    8.4.0            py39hd45dc43_0
# pip                       21.2.4           py39haa95532_0
# pkginfo                   1.7.1            py39haa95532_0
# plotly                    5.5.0                    pypi_0    pypi
# pluggy                    0.13.1           py39haa95532_0
# ply                       3.11             py39haa95532_0
# pooch                     1.6.0                    pypi_0    pypi
# powershell_shortcut       0.0.1                         3
# poyo                      0.5.0              pyhd3eb1b0_0
# prometheus_client         0.11.0             pyhd3eb1b0_0
# prompt-toolkit            3.0.20             pyhd3eb1b0_0
# prompt_toolkit            3.0.20               hd3eb1b0_0
# protego                   0.2.1              pyhd8ed1ab_0    conda-forge
# protobuf                  3.19.4                   pypi_0    pypi
# psutil                    5.8.0            py39h2bbff1b_1
# ptyprocess                0.7.0              pyhd3eb1b0_2
# py                        1.10.0             pyhd3eb1b0_0
# py-lief                   0.10.1           py39hd77b12b_1
# pyasn1                    0.4.8                      py_0    conda-forge
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pycodestyle               2.7.0              pyhd3eb1b0_0
# pycosat                   0.6.3            py39h2bbff1b_0
# pycparser                 2.20                       py_2
# pycurl                    7.44.1           py39hcd4344a_1
# pydictionary              2.0.1                    pypi_0    pypi
# pydispatcher              2.0.5                    pypi_0    pypi
# pydocstyle                6.1.1              pyhd3eb1b0_0
# pyerfa                    2.0.0            py39h2bbff1b_0
# pyflakes                  2.3.1              pyhd3eb1b0_0
# pygments                  2.10.0             pyhd3eb1b0_0
# pyhamcrest                2.0.3              pyhd8ed1ab_0    conda-forge
# pyjwt                     2.1.0            py39haa95532_0
# pylint                    2.9.6            py39haa95532_1
# pyls-spyder               0.4.0              pyhd3eb1b0_0
# pymongo                   4.2.0                    pypi_0    pypi
# pynacl                    1.4.0            py39hbd8134f_1
# pyodbc                    4.0.31           py39hd77b12b_0
# pyopenssl                 21.0.0             pyhd3eb1b0_1
# pyparsing                 3.0.4              pyhd3eb1b0_0
# pyqt                      5.9.2            py39hd77b12b_6
# pyreadline                2.1              py39haa95532_1
# pyrsistent                0.18.0           py39h196d8e1_0
# pysocks                   1.7.1            py39haa95532_0
# pytables                  3.6.1            py39h56d22b6_1
# pytest                    6.2.4            py39haa95532_2
# python                    3.9.7                h6244533_1
# python-dateutil           2.8.2              pyhd3eb1b0_0
# python-libarchive-c       2.9                pyhd3eb1b0_1
# python-lsp-black          1.0.0              pyhd3eb1b0_0
# python-lsp-jsonrpc        1.0.0              pyhd3eb1b0_0
# python-lsp-server         1.2.4              pyhd3eb1b0_0
# python-slugify            5.0.2              pyhd3eb1b0_0
# python_abi                3.9                      2_cp39    conda-forge
# pytz                      2021.3             pyhd3eb1b0_0
# pywavelets                1.1.1            py39h080aedc_4
# pywin32                   228              py39he774522_0
# pywin32-ctypes            0.2.0           py39haa95532_1000
# pywinpty                  0.5.7            py39haa95532_0
# pyyaml                    6.0              py39h2bbff1b_1
# pyzmq                     22.2.1           py39hd77b12b_1
# qdarkstyle                3.0.2              pyhd3eb1b0_0
# qstylizer                 0.1.10             pyhd3eb1b0_0
# qt                        5.9.7            vc14h73c81de_0
# qtawesome                 1.0.2              pyhd3eb1b0_0
# qtconsole                 5.1.1              pyhd3eb1b0_0
# qtpy                      1.10.0             pyhd3eb1b0_0
# queuelib                  1.6.2              pyhd8ed1ab_0    conda-forge
# regex                     2021.8.3         py39h2bbff1b_0
# requests                  2.26.0             pyhd3eb1b0_0
# requests-file             1.5.1              pyh9f0ad1d_0    conda-forge
# requests-oauthlib         1.3.1                    pypi_0    pypi
# rope                      0.19.0             pyhd3eb1b0_0
# rsa                       4.8                      pypi_0    pypi
# rtree                     0.9.7            py39h2eaa2aa_1
# ruamel_yaml               0.15.100         py39h2bbff1b_0
# scikit-image              0.18.3           py39hf11a4ad_0
# scikit-learn              0.24.2           py39hf11a4ad_1
# scikit-learn-intelex      2021.3.0         py39haa95532_0
# scipy                     1.7.1            py39hbe87c03_2
# scrapy                    2.6.1            py39haa95532_0
# seaborn                   0.11.2             pyhd3eb1b0_0
# selectorlib               0.16.0                   pypi_0    pypi
# selenium                  4.1.3                    pypi_0    pypi
# send2trash                1.8.0              pyhd3eb1b0_1
# sentence-transformers     2.2.2                    pypi_0    pypi
# sentencepiece             0.1.97                   pypi_0    pypi
# service-identity          21.1.0                   pypi_0    pypi
# service_identity          18.1.0                     py_0    conda-forge
# setuptools                58.0.4           py39haa95532_0
# simplegeneric             0.8.1            py39haa95532_2
# singledispatch            3.7.0           pyhd3eb1b0_1001
# sip                       4.19.13          py39hd77b12b_0
# six                       1.16.0             pyhd3eb1b0_0
# snappy                    1.1.8                h33f27b4_0
# sniffio                   1.2.0            py39haa95532_1
# snowballstemmer           2.1.0              pyhd3eb1b0_0
# sortedcollections         2.1.0              pyhd3eb1b0_0
# sortedcontainers          2.4.0              pyhd3eb1b0_0
# soupsieve                 2.2.1              pyhd3eb1b0_0
# sphinx                    4.2.0              pyhd3eb1b0_1
# sphinxcontrib             1.0              py39haa95532_1
# sphinxcontrib-applehelp   1.0.2              pyhd3eb1b0_0
# sphinxcontrib-devhelp     1.0.2              pyhd3eb1b0_0
# sphinxcontrib-htmlhelp    2.0.0              pyhd3eb1b0_0
# sphinxcontrib-jsmath      1.0.1              pyhd3eb1b0_0
# sphinxcontrib-qthelp      1.0.3              pyhd3eb1b0_0
# sphinxcontrib-serializinghtml 1.1.5              pyhd3eb1b0_0
# sphinxcontrib-websupport  1.2.4                      py_0
# spyder                    5.1.5            py39haa95532_1
# spyder-kernels            2.1.3            py39haa95532_0
# sqlalchemy                1.4.22           py39h2bbff1b_0
# sqlite                    3.36.0               h2bbff1b_0
# statsmodels               0.12.2           py39h2bbff1b_0
# stopwords                 1.0.0                    pypi_0    pypi
# sympy                     1.9              py39haa95532_0
# tbb                       2021.4.0             h59b6b97_0
# tbb4py                    2021.4.0         py39h59b6b97_0
# tblib                     1.7.0              pyhd3eb1b0_0
# tenacity                  8.0.1                    pypi_0    pypi
# tensorboard               2.8.0                    pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.1                    pypi_0    pypi
# tensorflow                2.8.0                    pypi_0    pypi
# tensorflow-io-gcs-filesystem 0.23.1                   pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.9.4            py39haa95532_0
# testpath                  0.5.0              pyhd3eb1b0_0
# text-unidecode            1.3                pyhd3eb1b0_0
# textdistance              4.2.1              pyhd3eb1b0_0
# tf-estimator-nightly      2.8.0.dev2021122109          pypi_0    pypi
# threadpoolctl             2.2.0              pyh0d69192_0
# three-merge               0.1.1              pyhd3eb1b0_0
# tifffile                  2021.7.2           pyhd3eb1b0_2
# tinycss                   0.4             pyhd3eb1b0_1002
# tk                        8.6.11               h2bbff1b_0
# tldextract                3.3.0              pyhd8ed1ab_0    conda-forge
# tokenizers                0.12.1                   pypi_0    pypi
# toml                      0.10.2             pyhd3eb1b0_0
# toolz                     0.11.1             pyhd3eb1b0_0
# torch                     1.12.1                   pypi_0    pypi
# torchvision               0.13.1                   pypi_0    pypi
# tornado                   6.1              py39h2bbff1b_0
# tqdm                      4.62.3             pyhd3eb1b0_1
# traitlets                 5.1.0              pyhd3eb1b0_0
# transformers              4.22.1                   pypi_0    pypi
# trio                      0.20.0                   pypi_0    pypi
# trio-websocket            0.9.2                    pypi_0    pypi
# twisted                   22.4.0                   pypi_0    pypi
# twisted-iocpsupport       1.0.2            py39hb82d6ee_2    conda-forge
# typed-ast                 1.4.3            py39h2bbff1b_1
# typing_extensions         3.10.0.2           pyh06a4308_0
# tzdata                    2021e                hda174b7_0
# ujson                     4.0.2            py39hd77b12b_0
# unicodecsv                0.14.1           py39haa95532_0
# unidecode                 1.2.0              pyhd3eb1b0_0
# urllib3                   1.26.7             pyhd3eb1b0_0
# vadersentiment            3.3.2                    pypi_0    pypi
# vc                        14.2                 h21ff451_1
# vs2015_runtime            14.27.29016          h5e58377_2
# w3lib                     1.22.0             pyh9f0ad1d_0    conda-forge
# watchdog                  2.1.3            py39haa95532_0
# wcwidth                   0.2.5              pyhd3eb1b0_0
# webencodings              0.5.1            py39haa95532_1
# werkzeug                  2.0.2              pyhd3eb1b0_0
# wheel                     0.37.0             pyhd3eb1b0_1
# whichcraft                0.6.1              pyhd3eb1b0_0
# widgetsnbextension        3.5.1            py39haa95532_0
# win_inet_pton             1.1.0            py39haa95532_0
# win_unicode_console       0.5              py39haa95532_0
# wincertstore              0.2              py39haa95532_2
# winpty                    0.4.3                         4
# wordcloud                 1.8.1            py39hb82d6ee_2    conda-forge
# wrapt                     1.12.1           py39h196d8e1_1
# wsproto                   1.1.0                    pypi_0    pypi
# xgboost                   1.5.2                    pypi_0    pypi
# xlrd                      2.0.1              pyhd3eb1b0_0
# xlsxwriter                3.0.1              pyhd3eb1b0_0
# xlwings                   0.24.9           py39haa95532_0
# xlwt                      1.3.0            py39haa95532_0
# xmltodict                 0.12.0             pyhd3eb1b0_0
# xz                        5.2.5                h62dcd97_0
# yaml                      0.2.5                he774522_0
# yapf                      0.31.0             pyhd3eb1b0_0
# zfp                       0.5.5                hd77b12b_6
# zict                      2.0.0              pyhd3eb1b0_0
# zipp                      3.6.0              pyhd3eb1b0_0
# zlib                      1.2.11               h62dcd97_4
# zope                      1.0              py39haa95532_1
# zope.event                4.5.0            py39haa95532_0
# zope.interface            5.4.0            py39h2bbff1b_0
# zstd                      1.4.9                h19a0ad4_0

# %%
pip install tensorflow_hub
# Out:
# Collecting tensorflow_hubNote: you may need to restart the kernel to use updated packages.
#   Using cached tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\neema\anaconda3\lib\site-packages (from tensorflow_hub) (1.20.3)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\neema\anaconda3\lib\site-packages (from tensorflow_hub) (3.19.4)
# Installing collected packages: tensorflow-hub
# Successfully installed tensorflow-hub-0.12.0

# %%
import itertools
import re

import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import tensorflow_hub as hub
from scipy.spatial import distance
from sklearn.preprocessing import StandardScaler

# %%
def split_text_into_sentences(text):
    """Splits a given text into multiple sentences using RegEx"""
    return re.split(r'(?<=[^A-Z].[.?]) +(?=[A-Z])', text)

# %%
def get_average_similarity(model, ps1, ps2):
    """Calculates the average of the similarity score based on all the combinations of these two lists of texts.
    This function uses Sentence Transformers model."""
    sm_scores = []  # list to store similarity scores for each combination of post texts.
    try:
        sembs_1 = model.encode(ps1)  # Sentence embeddings for the first list of posts
        sembs_2 = model.encode(ps2)  # Sentence embeddings for the second list of posts

        # Iterating through each of the first list of embeddings and finding cosine similarity with the second list of embeddings
        for semb in sembs_1:
            sm_scores.extend(cosine_similarity([semb], sembs_2))
    except Exception as e:
        print(e)
        print(ps1)
        print(ps2)
    # Taking the average of the scores. Can take median as well.
    return np.mean(sm_scores)

# %%
def get_median_similarity(model, ps1, ps2):
    """Calculates the average of the similarity score based on all the combinations of these two lists of texts.
    Using the Universal sentence encoder model."""
    sm_scores = []
    try:
        sembs_1 = model(ps1).numpy()  # Sentence embeddings for the first list of posts
        sembs_2 = model(ps2).numpy()  # Sentence embeddings for the second list of posts

        for semb in sembs_1:
            sm_scores.extend(cosine_similarity([semb], sembs_2))
    except Exception as e:
        print(e)
        # print(ps1)
        # print(ps2)
    return np.median(sm_scores)

# %%
def get_inverse_distance_similarity(model, ps1, ps2):
    """Find the similarity by calculating the overlap between the clusters of both the embeddings.
    Using the Universal sentence encoder model."""
    inverse_distance = 0
    try:
        sembs_1 = model(ps1).numpy()  # Sentence embeddings for the first list of posts
        sembs_2 = model(ps2).numpy()  # Sentence embeddings for the second list of posts

        sembs_1_centroid = np.mean(sembs_1, axis=0)
        # Getting the centroid for the first list of embeddings. Assuming that they form a cluster in the n-dim space.
        sembs_2_centroid = np.mean(sembs_2, axis=0)

        inverse_distance = 1 / distance.cdist([sembs_1_centroid], [sembs_2_centroid])[0][0]
    except Exception as e:
        print(e)
        print(ps1)
        print(ps2)
    return inverse_distance

# %%
def get_overlap_similarity(model, ps1, ps2):
    """Find the similarity by calculating the overlap between the clusters of both the embeddings.
    This function uses Sentence Transformers model."""
    similarity_score = 0
    try:
        sembs_1 = model.encode(ps1)  # Sentence embeddings for the first list of posts
        sembs_2 = model.encode(ps2)  # Sentence embeddings for the second list of posts

        # Getting the centroid for the first list of embeddings. Assuming that they form a cluster in the n-dim space.
        sembs_1_centroid = np.mean(sembs_1, axis=0)
        sembs_1_radius = np.max(distance.cdist(sembs_1, [sembs_1_centroid]))
        # Taking the max distance among all the points in the first cluster as the radius of the cluster.

        sembs_2_dists = distance.cdist(sembs_2, [sembs_1_centroid])
        # Getting all the distances of the points in the second cluster from the centroid of the first cluster.
        n_A_or_B = len(sembs_1) + len(sembs_2)  # Union of both the clusters.
        n_A_and_B = len(sembs_2_dists[sembs_2_dists <= sembs_1_radius])
        # Intersection of the clusters is calculated by taking the number of points from the second cluster that are present within the radius of the first cluster.
        similarity_score = round(n_A_and_B / n_A_or_B, 4)  # Ratio of intersection over union.
    except Exception as e:
        print(e)
        print(ps1)
        print(ps2)
    return similarity_score

# %%
def get_vito_similarity(model, ps1, ps2, vito_number):
    """Find the similarity by calculating the overlap between the clusters of both the embeddings.
    Using the Universal sentence encoder model."""
    similarity_score = 0
    scaler = StandardScaler()
    try:
        sembs_1 = model(ps1).numpy()  # Sentence embeddings for the first list of posts
        sembs_2 = model(ps2).numpy()  # Sentence embeddings for the second list of posts

        sembs_1 = scaler.fit_transform(sembs_1)
        sembs_2 = scaler.fit_transform(sembs_2)

        sembs_1_centroid = np.mean(sembs_1, axis=0)
        sembs_2_centroid = np.mean(sembs_2, axis=0)

        similarity_score = distance.cdist([sembs_1_centroid], [sembs_2_centroid])[0][0] / vito_number
    except Exception as e:
        print(e)
        print(ps1)
        print(ps2)
    return similarity_score

# %%
def get_vito_number(model, text_corpus):
    """Find the maximum possible distance in the n-dim hyperspace."""
    sembs = model(text_corpus).numpy()
    # print(sembs.shape)
    scaler = StandardScaler()
    sembs = scaler.fit_transform(sembs)
    # print(np.max(sembs, axis=0) - np.min(sembs, axis=0))
    return np.sqrt(np.sum((np.max(sembs, axis=0) - np.min(sembs, axis=0)) ** 2))

# %%
def influencer_influencer_similarity(sentence_split=False):
    """Do the similarity analysis between all the influencers"""
    df_influencers = pd.read_csv('preprocessed_data_inf_without_punc.csv')
    df_influencers.dropna(inplace=True)
    df_influencers = df_influencers[df_influencers['platform'] != 'website']

    # Loading the sentence transformers model.
    # bert_model = SentenceTransformer('bert-base-nli-mean-tokens')
    use_model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

    # vito_number = get_vito_number(use_model, df_competitors['text'].tolist())
    # print('Vito number', vito_number)

    # Getting unique values of competitor and influencer names as a list
    infu_list = df_influencers['influencer_username'].unique().tolist()

    final_scores = []
    # Iterating through all the combinations of competitors
    for ns in itertools.combinations(infu_list, 2):
        infu1, infu2 = ns[0], ns[1]
        # Skipping for the same competitor combination
        if infu1 == infu2:
            continue

        # Getting all the posts belonging to the competitor given by 'cmptr1'
        infu1_posts = df_influencers.loc[df_influencers['influencer_username'] == infu1, 'text'].tolist()
        infu2_posts = df_influencers.loc[df_influencers['influencer_username'] == infu2, 'text'].tolist()

        # If sentence split is enabled, will split the posts into sentences.
        if sentence_split:
            stcs = []
            for post in cmptr1_posts:
                stcs.extend(split_text_into_sentences(post))
            infu1_posts = stcs.copy()

            stcs = []
            for post in infu2_posts:
                stcs.extend(split_text_into_sentences(post))
            infu2_posts = stcs.copy()

        print('Finding similarity between the influencers 1', infu1, ' and the influencers 2', infu2, '...')
        # Appending to the list of similarity scores for each combination of competitors
        final_scores.append(
            (infu1, infu2,
             get_median_similarity(model=use_model, ps1=infu1_posts, ps2=infu2_posts)))

        df_similarity = pd.DataFrame(final_scores, columns=['influencer_1', 'influencer_2', 'similarity_score'])
        df_similarity.to_csv('influencer_influencer_similarity.csv', index=False)


# competitor_competitor_similarity(sentence_split=False)
influencer_influencer_similarity()
# Out:
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 adamcollard ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 aliceliveing ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 brown.elle ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 charlottedawsy ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 chessieking ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 chloe.khan ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 courtneydblack ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 danosborneofficial ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 gabbydawnallen ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 aaroncgshore  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 aliceliveing ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 brown.elle ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 charlottedawsy ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 chessieking ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 chloe.khan ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 courtneydblack ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 danosborneofficial ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 gabbydawnallen ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 adamcollard  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 brown.elle ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 charlottedawsy ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 chessieking ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 chloe.khan ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 courtneydblack ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 danosborneofficial ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 gabbydawnallen ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 aliceliveing  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 charlottedawsy ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 chessieking ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 chloe.khan ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 courtneydblack ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 danosborneofficial ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 gabbydawnallen ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 brown.elle  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 chessieking ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 chloe.khan ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 courtneydblack ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 danosborneofficial ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 gabbydawnallen ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 charlottedawsy  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 chloe.khan ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 courtneydblack ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 danosborneofficial ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 gabbydawnallen ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 chessieking  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 courtneydblack ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 danosborneofficial ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 gabbydawnallen ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 chloe.khan  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 danosborneofficial ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 gabbydawnallen ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 courtneydblack  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 gabbydawnallen ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 danosborneofficial  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 ini.helen ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 gabbydawnallen  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 itsalwayshana ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 ini.helen  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 jamesgshore ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 itsalwayshana  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 jamessmithpt ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 jamesgshore  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 jesshunt2 ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 jamessmithpt  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 jessica_rose_uk ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 jesshunt2  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 jesswright77 ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 jessica_rose_uk  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 katiepiper_ ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 jesswright77  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 korisampson ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 katiepiper_  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 lucymeck1 ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 korisampson  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 mac_griffiths_ ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 lucymeck1  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 mac_griffiths_  and the influencers 2 mattdoesfitness ...
# Finding similarity between the influencers 1 mac_griffiths_  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 mac_griffiths_  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 mac_griffiths_  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 mac_griffiths_  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 mac_griffiths_  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 mac_griffiths_  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 mac_griffiths_  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 mac_griffiths_  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 mattdoesfitness  and the influencers 2 ohpolly ...
# Finding similarity between the influencers 1 mattdoesfitness  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 mattdoesfitness  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 mattdoesfitness  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 mattdoesfitness  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 mattdoesfitness  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 mattdoesfitness  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 mattdoesfitness  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 ohpolly  and the influencers 2 oliviadbowen ...
# Finding similarity between the influencers 1 ohpolly  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 ohpolly  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 ohpolly  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 ohpolly  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 ohpolly  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 ohpolly  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 oliviadbowen  and the influencers 2 rogersnipes ...
# Finding similarity between the influencers 1 oliviadbowen  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 oliviadbowen  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 oliviadbowen  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 oliviadbowen  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 oliviadbowen  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 rogersnipes  and the influencers 2 slimmingworld ...
# Finding similarity between the influencers 1 rogersnipes  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 rogersnipes  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 rogersnipes  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 rogersnipes  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 slimmingworld  and the influencers 2 sylvijaa ...
# Finding similarity between the influencers 1 slimmingworld  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 slimmingworld  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 slimmingworld  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 sylvijaa  and the influencers 2 thebodycoach ...
# Finding similarity between the influencers 1 sylvijaa  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 sylvijaa  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 thebodycoach  and the influencers 2 thefitnesschef_ ...
# Finding similarity between the influencers 1 thebodycoach  and the influencers 2 _jackfowler_ ...
# Finding similarity between the influencers 1 thefitnesschef_  and the influencers 2 _jackfowler_ ...
