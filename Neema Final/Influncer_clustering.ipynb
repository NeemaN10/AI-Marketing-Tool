# %%
pip install seaborn
# Out:
# ...
#
# ...
#      -------------------------------------- 288.2/288.2 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn import datasets
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
#Reading dataset-- influencer_influencer_similarity
data1=pd.read_csv(r"C:\Users\neema\OneDrive\Desktop\Neema\Essex Class\dissertation\Neema_inf\Neema Updated Final\influencer_influencer_similarity.csv", low_memory=False)

# %%
x = data1.iloc[:, [2]]
x  = np.array(x)

# %%
kmeans_kwargs = {
     "init": "random",
     "n_init": 10,
     "max_iter": 300,
     "random_state": 42,
     }

# %%
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []
# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 12):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(x)
    score = silhouette_score(x, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
#K-means clustering to cluster the influencers which are similar to each other.
kmeans_model = KMeans(n_clusters=3,  random_state=32932)
# Fit into our dataset fit
kmeans_predict = kmeans_model.fit_predict(x)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(2, 12), silhouette_coefficients)
plt.xticks(range(2, 12))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %%
#Forming the cluster column
data1['Cluster'] = kmeans_predict

# %%
kmeans_predict = KMeans(n_clusters=3)
kmeans_predict.fit(x)
labels=kmeans.labels_
Influencer=pd.DataFrame(list(zip(data1['influencer_username'],labels)),columns=['influencer_username','cluster'])
print(Influencer.sort_values(by=['cluster']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'influencer_username'
#
# ...

# %%
print(data1['Cluster'].unique())
# Out:
# [0 1 2]

# %%
print (a)
# Out:
#         influencer_1     influencer_2  similarity_score  Cluster
# 0       aaroncgshore      adamcollard          0.054276        0
# 1       aaroncgshore     aliceliveing          0.063736        0
# 2       aaroncgshore       brown.elle          0.060118        0
# 4       aaroncgshore      chessieking          0.093043        0
# 5       aaroncgshore       chloe.khan          0.077262        0
# ..               ...              ...               ...      ...
# 429         sylvijaa     thebodycoach          0.058987        0
# 430         sylvijaa  thefitnesschef_          0.027763        0
# 431         sylvijaa     _jackfowler_          0.070104        0
# 433     thebodycoach     _jackfowler_          0.083965        0
# 434  thefitnesschef_     _jackfowler_          0.052943        0
#
# [289 rows x 4 columns]

# %%
x1=data1[(data1['Cluster']==1)]
x1.head(20)
# Out:
#     influencer_1        influencer_2  similarity_score  Cluster
# 3   aaroncgshore      charlottedawsy          0.130014        1
# 7   aaroncgshore  danosborneofficial          0.120499        1
# 31   adamcollard      charlottedawsy          0.131929        1
# 32   adamcollard         chessieking          0.138872        1
# 35   adamcollard  danosborneofficial          0.098070        1
# 36   adamcollard      gabbydawnallen          0.157930        1
# 38   adamcollard       itsalwayshana          0.136519        1
# 44   adamcollard         katiepiper_          0.126072        1
# 46   adamcollard           lucymeck1          0.116981        1
# 48   adamcollard     mattdoesfitness          0.104216        1
# 49   adamcollard             ohpolly          0.136426        1
# 50   adamcollard        oliviadbowen          0.100978        1
# 51   adamcollard         rogersnipes          0.149421        1
# 54   adamcollard        thebodycoach          0.146116        1
# ...

# %%
#Reading dataset-- competitor_influencer_similarity
data2=pd.read_csv(r"C:\Users\neema\OneDrive\Desktop\Neema\Essex Class\dissertation\Neema_inf\Neema Updated Final\competitor_influencer_similarity.csv", low_memory=False)

# %%
data2
# Out:
#     competitor_name  influencer_name  similarity_score  Cluster
# 0              bulk     aaroncgshore          0.052173        0
# 1              bulk      adamcollard          0.112365        1
# 2              bulk     aliceliveing          0.105055        3
# 3              bulk       brown.elle          0.031806        2
# 4              bulk   charlottedawsy          0.096758        3
# ..              ...              ...               ...      ...
# 295       puresport    slimmingworld          0.168555        4
# 296       puresport         sylvijaa          0.045350        2
# 297       puresport     thebodycoach          0.110334        1
# 298       puresport  thefitnesschef_          0.122526        1
# 299       puresport     _jackfowler_          0.074444        0
#
# [300 rows x 4 columns]

# %%
y = data2.iloc[:, [2]]
y  = np.array(y)

# %%
#K-means clustering to find the competitors name which is close to which cluster influencer
kmeans_model1 = KMeans(n_clusters=5,  random_state=32932)
# Fit into our dataset fit
kmeans_predict1 = kmeans_model1.fit_predict(y)

# %%
#Forming the cluster column
data2['Cluster'] = kmeans_predict1

# %%
print(data2['Cluster'].unique())
# Out:
# [0 1 3 2 4]

# %%
da

# %%
a1=data2[(data2['Cluster']==0)]
a1.head(20)
# Out:
#    competitor_name     influencer_name  similarity_score  Cluster
# 0             bulk        aaroncgshore          0.052173        0
# 6             bulk          chloe.khan          0.055821        0
# 8             bulk  danosborneofficial          0.076872        0
# 11            bulk       itsalwayshana          0.071972        0
# 12            bulk         jamesgshore          0.066546        0
# 13            bulk        jamessmithpt          0.064629        0
# 16            bulk        jesswright77          0.059196        0
# 18            bulk         korisampson          0.054819        0
# 20            bulk      mac_griffiths_          0.063522        0
# 21            bulk     mattdoesfitness          0.076187        0
# 23            bulk        oliviadbowen          0.077506        0
# 29            bulk        _jackfowler_          0.070944        0
# 38   formnutrition  danosborneofficial          0.067320        0
# ...

# %%
def get_median_similarity(model, ps1, ps2):
    """Calculates the average of the similarity score based on all the combinations of these two lists of texts.
    Using the Universal sentence encoder model."""
    sm_scores = []
    try:
        sembs_1 = model(ps1).numpy()  # Sentence embeddings for the first list of posts
        sembs_2 = model(ps2).numpy()  # Sentence embeddings for the second list of posts

        for semb in sembs_1:
            sm_scores.extend(cosine_similarity([semb], sembs_2))
    except Exception as e:
        print(e)
        # print(ps1)
        # print(ps2)
    return np.median(sm_scores)

# %%
data_1=a1.groupby(['competitor_name','Cluster','similarity_score']).first()

# %%
data_1
# Out:
#                                              influencer_name
# competitor_name Cluster similarity_score
# bulk            0       0.052173                aaroncgshore
#                         0.054819                 korisampson
#                         0.055821                  chloe.khan
#                         0.059196                jesswright77
#                         0.063522              mac_griffiths_
# ...                                                      ...
# thenue_co       0       0.053397              mac_griffiths_
#                         0.056676                jesswright77
#                         0.060161             mattdoesfitness
#                         0.062816                _jackfowler_
#                         0.063144          danosborneofficial
#
# [106 rows x 1 columns]
